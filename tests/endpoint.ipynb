# %%
from huggingface_hub import InferenceClient

client = InferenceClient(model = "https://sz8hb6gcq2ersref.us-east-1.aws.endpoints.huggingface.cloud", token="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")
json = {"inputs": "love, heartbreak, slow, country"}
response = client.post(json=json)
# response looks like this b'[{"generated_text":[[-0.182352,-0.17802449, ...]]}]

output = eval(response)[0]["generated_audio"]

# %%
from IPython.display import Audio
Audio(output, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
