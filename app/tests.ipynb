# %%
import json
import requests
API_URL = "https://api-inference.huggingface.co/models/facebook/musicgen-small"
headers = {"Authorization": "Bearer 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"}

async def query(payload):
    data = json.dumps(payload)
    response = requests.request("POST", API_URL, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))
data = await query({"inputs": ["80s ballad", "love song", "pop"]})

# %%
print(data)
# Out:
# {'error': 'Internal Server Error'}

# %%
url = 'https://youtube.googleapis.com/youtube/v3/search'
params = {
    'part': 'snippet',
    'q': 'Buzz Caosn',
    'type': '',
    'key': google_key,
    'maxResults': '25'
}
response = requests.get(url, params=params)
response.json()
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'prewmxgztiwsWGmpQVgFlE6pLqo',
#  'nextPageToken': 'CBkQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 44986, 'resultsPerPage': 25},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'K_APR-3w74w3qLiLhk2P5smeh2c',
#    'id': {'kind': 'youtube#video', 'videoId': 'CyHpxlvqMBE'},
#    'snippet': {'publishedAt': '2020-12-23T14:22:49Z',
#     'channelId': 'UC_mMZUjNamr0EE6pKMel3VQ',
#     'title': 'Buzz Cason ~ Everlasting Love',
#     'description': 'Everlasting Love by Buzz Cason - from Rock & Roll Graffiti.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CyHpxlvqMBE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CyHpxlvqMBE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CyHpxlvqMBE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'JymSea',
# ...

# %%
# Create a pandas dataframe from the response
response_dict = response.json()

# Create a pandas dataframe from the snippets
snippets_df = pd.DataFrame(response_dict['items'])

# %%
snippet_df = snippets_df['snippet']

# %%
snippet_df
# Out:
# 0     {'publishedAt': '2020-12-23T14:22:49Z', 'chann...
# 1     {'publishedAt': '2014-05-01T14:46:08Z', 'chann...
# 2     {'publishedAt': '2017-07-23T20:23:38Z', 'chann...
# 3     {'publishedAt': '2014-05-01T16:09:07Z', 'chann...
# 4     {'publishedAt': '2013-11-22T16:30:09Z', 'chann...
# 5     {'publishedAt': '2006-12-08T17:57:26Z', 'chann...
# 6     {'publishedAt': '2021-07-30T13:47:33Z', 'chann...
# 7     {'publishedAt': '2019-08-19T12:56:30Z', 'chann...
# 8     {'publishedAt': '2014-10-28T20:00:14Z', 'chann...
# 9     {'publishedAt': '2021-06-18T03:14:18Z', 'chann...
# 10    {'publishedAt': '2010-08-26T10:05:56Z', 'chann...
# 11    {'publishedAt': '2015-04-22T06:50:12Z', 'chann...
# 12    {'publishedAt': '2011-02-19T04:51:08Z', 'chann...
# 13    {'publishedAt': '2010-08-27T22:44:26Z', 'chann...
# 14    {'publishedAt': '2018-12-23T12:14:55Z', 'chann...
# 15    {'publishedAt': '2021-08-31T08:45:41Z', 'chann...
# 16    {'publishedAt': '2018-12-26T21:17:42Z', 'chann...
# ...

# %%
snippet_df = [snippet for snippet in snippet_df]

# %%
df = pd.DataFrame()
for snippet in snippet_df:
    temp_df = pd.Series(snippet)
    df = pd.concat([df, temp_df], axis=1)

# %%
df.head()
# Out:
#                                                              0  \
# publishedAt                               2020-12-23T14:22:49Z
# channelId                             UC_mMZUjNamr0EE6pKMel3VQ
# title                            Buzz Cason ~ Everlasting Love
# description  Everlasting Love by Buzz Cason - from Rock & R...
# thumbnails   {'default': {'url': 'https://i.ytimg.com/vi/Cy...
#
#                                                              0  \
# publishedAt                               2014-05-01T14:46:08Z
# channelId                             UCw3MoVRyZhx98_VQ578SNQw
# title                   Buzz Cason Troubadour Heart Video 5114
# description                      Buzz Cason "Troubadour Heart"
# thumbnails   {'default': {'url': 'https://i.ytimg.com/vi/VU...
#
#                                                              0  \
# publishedAt                               2017-07-23T20:23:38Z
# channelId                             UCoR5PhGUrmKYmcbB0-Yi2WA
# ...
